# %% [markdown]
# ## Import Libraries.

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Creating DataFrame

# %%
# using 2D lists. 
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data, columns=['IQ', 'Marks', 'Package'])
# Out:
#     IQ  Marks  Package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dictionary. 
student_dict = {
    'IQ' : [100, 90, 120, 80], 
    'Marks' : [80, 70, 100, 50], 
    'Package' : [10, 7, 14, 2]
}

students = pd.DataFrame(student_dict)
students
# Out:
#     IQ  Marks  Package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using read_csv. 
movies = pd.read_csv('./Datasets/movies.csv')
ipl = pd.read_csv('./Datasets/ipl-matches.csv')

# %% [markdown]
# `NOTE : `
# - using read_csv() pandas always convert the data into a dataframe, that has row and columns.
# - Each row is a series as well as each column is also a series.

# %% [markdown]
# ### DataFrame Attributes.

# %%
# shape.

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# index

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# values

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# columns.

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %% [markdown]
# ### DataFrame functions.

# %%
# head()

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# tail function

# %%
movies.tail(2)
# Out:
#        title_x     imdb_id                                        poster_path  \
# 1627     Daaka  tt10833860  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  Humsafar   tt2403201  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                    wiki_link   title_y original_title  \
# 1627     https://en.wikipedia.org/wiki/Daaka     Daaka          Daaka
# 1628  https://en.wikipedia.org/wiki/Humsafar  Humsafar       Humsafar
#
#       is_adult  year_of_release runtime         genres  imdb_rating  \
# 1627         0             2019     136         Action          7.4
# 1628         0             2011      35  Drama|Romance          9.0
#
#       imdb_votes                                              story  \
# 1627          38  Shinda tries robbing a bank so he can be wealt...
# 1628        2968  Sara and Ashar are childhood friends who share...
#
#                                                 summary tagline  \
# ...

# %%
# sample
ipl.sample()
# Out:
#           ID   City        Date Season MatchNumber             Team1  \
# 329  1082635  Delhi  2017-05-06   2017          45  Delhi Daredevils
#
#               Team2             Venue        TossWinner TossDecision  \
# 329  Mumbai Indians  Feroz Shah Kotla  Delhi Daredevils        field
#
#     SuperOver     WinningTeam WonBy  Margin method Player_of_Match  \
# 329         N  Mumbai Indians  Runs   146.0    NaN     LMP Simmons
#
#                                           Team1Players  \
# 329  ['SV Samson', 'KK Nair', 'SS Iyer', 'RR Pant',...
#
#                                           Team2Players      Umpire1    Umpire2
# 329  ['LMP Simmons', 'PA Patel', 'KA Pollard', 'RG ...  Nitin Menon  CK Nandan

# %%
movies.sample()
# Out:
#                    title_x    imdb_id  \
# 1557  Waah! Tera Kya Kehna  tt0339878
#
#                                             poster_path  \
# 1557  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 1557  https://en.wikipedia.org/wiki/Waah!_Tera_Kya_K...  Waah! Tera Kya Kehna
#
#             original_title  is_adult  year_of_release runtime  genres  \
# 1557  Waah! Tera Kya Kehna         0             2002      \N  Comedy
#
#       imdb_rating  imdb_votes  \
# 1557          3.7         203
#
#                                                   story  \
# 1557  Kishan Oberoi (Shammi Kapoor) has three sons D...
#
#                                                 summary tagline  \
# 1557  Kishan Oberoi (Shammi Kapoor) has three sons D...     NaN
#
#                                                  actors wins_nominations  \
# 1557  Govinda|Raveena Tandon|Preeti Jhangiani|Shakti...              NaN
# ...

# %%
# info function. 
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe function  --> This function provide me the detail of mathematical observations on numerical columns

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull function : return the boolean DataFrame.

# %%
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicated function

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
# rename function.
students
# Out:
#     IQ  Marks  Package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
students.rename(columns={'Marks' : 'Percentage', 'Package' : 'LPA'}, inplace=True)

# %%
students
# Out:
#     IQ  Percentage  LPA
# 0  100          80   10
# 1   90          70    7
# 2  120         100   14
# 3   80          50    2

# %% [markdown]
# ### Maths Methods.

# %%
# sum  --> axis argument. 

# it will give me the sum column wise. 
students.sum()
# Out:
# IQ            390
# Percentage    300
# LPA            33
# dtype: int64

# %%
# it will return the sum row wise.
students.sum(axis=1)
# Out:
# 0    190
# 1    167
# 2    234
# 3    132
# dtype: int64

# %% [markdown]
# `Here all the Mathematical functions are avilable`
# - mean
# - median
# - mode
# - std
# - var
# - min
# - max

# %% [markdown]
# ### Selecting cols from a DataFrame

# %%
# single column

# %%
movies['original_title']
# Out:
# 0            Uri: The Surgical Strike
# 1                       Battalion 609
# 2       The Accidental Prime Minister
# 3                     Why Cheat India
# 4                     Evening Shadows
#                     ...
# 1624            Tera Mera Saath Rahen
# 1625             Yeh Zindagi Ka Safar
# 1626                  Sabse Bada Sukh
# 1627                            Daaka
# 1628                         Humsafar
# Name: original_title, Length: 1629, dtype: object

# %%
ipl['WinningTeam']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2      Royal Challengers Bangalore
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945          Kolkata Knight Riders
# 946    Royal Challengers Bangalore
# 947               Delhi Daredevils
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: WinningTeam, Length: 950, dtype: object

# %%
# Multiple Columns --> using fancy indexing
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# It will return in that order, in which order we provide the name in the list.
movies[['imdb_votes', 'imdb_rating', 'title_x']]
# Out:
#       imdb_votes  imdb_rating                               title_x
# 0          35112          8.4              Uri: The Surgical Strike
# 1             73          4.1                         Battalion 609
# 2           5549          6.1  The Accidental Prime Minister (film)
# 3           1891          6.0                       Why Cheat India
# 4            280          7.3                       Evening Shadows
# ...          ...          ...                                   ...
# 1624         278          4.9                 Tera Mera Saath Rahen
# 1625         133          3.0                  Yeh Zindagi Ka Safar
# 1626          13          6.1                       Sabse Bada Sukh
# 1627          38          7.4                                 Daaka
# 1628        2968          9.0                              Humsafar
#
# [1629 rows x 3 columns]

# %%
ipl[['Team1', 'Team2', 'WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# ### Selecting rows from a DataFrame
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels
#
# `NOTE : `  There is an internal indexing that is manage by pandas internally for both rows and columns, iloc completely works on that index.

# %%
# single row access from dataframe. 
movies.iloc[2]
# Out:
# title_x                          The Accidental Prime Minister (film)
# imdb_id                                                     tt6986710
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/The_Accidental_P...
# title_y                                 The Accidental Prime Minister
# original_title                          The Accidental Prime Minister
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           112
# genres                                                Biography|Drama
# imdb_rating                                                       6.1
# imdb_votes                                                       5549
# story               Based on the memoir by Indian policy analyst S...
# ...

# %%
ipl.iloc[67]
# Out:
# ID                                                           1304053
# City                                                          Mumbai
# Date                                                      2022-03-31
# Season                                                          2022
# MatchNumber                                                        7
# Team1                                            Chennai Super Kings
# Team2                                           Lucknow Super Giants
# Venue                                      Brabourne Stadium, Mumbai
# TossWinner                                      Lucknow Super Giants
# TossDecision                                                   field
# SuperOver                                                          N
# WinningTeam                                     Lucknow Super Giants
# WonBy                                                        Wickets
# Margin                                                           6.0
# ...

# %%
# Multiple rows access from the dataframe.

# %%
# using the concept of slicing in pyhton. 
ipl.iloc[3 : 11 : 2]
# Out:
#         ID     City        Date Season  MatchNumber                Team1  \
# 3  1312197  Kolkata  2022-05-24   2022  Qualifier 1     Rajasthan Royals
# 5  1304115   Mumbai  2022-05-21   2022           69       Delhi Capitals
# 7  1304113   Mumbai  2022-05-19   2022           67       Gujarat Titans
# 9  1304111   Mumbai  2022-05-17   2022           65  Sunrisers Hyderabad
#
#                          Team2                     Venue      TossWinner  \
# 3               Gujarat Titans     Eden Gardens, Kolkata  Gujarat Titans
# 5               Mumbai Indians  Wankhede Stadium, Mumbai  Mumbai Indians
# 7  Royal Challengers Bangalore  Wankhede Stadium, Mumbai  Gujarat Titans
# 9               Mumbai Indians  Wankhede Stadium, Mumbai  Mumbai Indians
#
#   TossDecision SuperOver                  WinningTeam    WonBy  Margin method  \
# 3        field         N               Gujarat Titans  Wickets     7.0    NaN
# ...

# %%
# using fancy indexing also. 
ipl.iloc[[2, 3, 6, 8, 9]]
# Out:
#         ID         City        Date Season  MatchNumber  \
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 6  1304114       Mumbai  2022-05-20   2022           68
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                  Team2  \
# 2  Royal Challengers Bangalore   Lucknow Super Giants
# 3             Rajasthan Royals         Gujarat Titans
# 6          Chennai Super Kings       Rajasthan Royals
# 8         Lucknow Super Giants  Kolkata Knight Riders
# 9          Sunrisers Hyderabad         Mumbai Indians
#
#                                 Venue            TossWinner TossDecision  \
# 2               Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3               Eden Gardens, Kolkata        Gujarat Titans        field
# 6           Brabourne Stadium, Mumbai   Chennai Super Kings          bat
# ...

# %%
# loc function

# %%
student_dict = {
    'Name' : ['Nitish', 'Ankita', 'Uzaif', 'Ankit', 'Amit', 'Rishabh'], 
    'IQ' : [100, 90, 120, 80, 95, 80], 
    'Marks' : [80, 70, 100, 50, 95, 80], 
    'Package' : [10, 7, 14, 2, 9, 8]
}

students = pd.DataFrame(student_dict)
students.set_index('Name', inplace=True)
students
# Out:
#           IQ  Marks  Package
# Name
# Nitish   100     80       10
# Ankita    90     70        7
# Uzaif    120    100       14
# Ankit     80     50        2
# Amit      95     95        9
# Rishabh   80     80        8

# %% [markdown]
# `NOTE :` Here one thing is observable that we labelled the index with the name, but indernally pandas manage the one more index starting with zero for both rows and columns

# %%
students.loc['Nitish']
# Out:
# IQ         100
# Marks       80
# Package     10
# Name: Nitish, dtype: int64

# %%
# here we see the last index is included whereas in iloc it is excluded.
students.loc['Nitish' : 'Amit']
# Out:
#          IQ  Marks  Package
# Name
# Nitish  100     80       10
# Ankita   90     70        7
# Uzaif   120    100       14
# Ankit    80     50        2
# Amit     95     95        9

# %%
# using fancy indexing. 
students.loc[['Nitish', 'Uzaif', 'Ankita']]
# Out:
#          IQ  Marks  Package
# Name
# Nitish  100     80       10
# Uzaif   120    100       14
# Ankita   90     70        7

# %% [markdown]
# ### Selecting both rows and columns.

# %%
# using iloc function.
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
movies.iloc[7 : 11, 4 : 9]
# Out:
#                              title_y                    original_title  \
# 7                         Bombairiya                        Bombairiya
# 8   Manikarnika: The Queen of Jhansi  Manikarnika: The Queen of Jhansi
# 9                          Thackeray                         Thackeray
# 10                            Amavas                            Amavas
#
#     is_adult  year_of_release runtime
# 7          0             2019     104
# 8          0             2019     148
# 9          0             2019     120
# 10         0             2019     134

# %%
students.loc['Nitish' : 'Uzaif', 'IQ' : 'Package']
# Out:
#          IQ  Marks  Package
# Name
# Nitish  100     80       10
# Ankita   90     70        7
# Uzaif   120    100       14

# %%
movies.loc[0 : 10 : 2, 'poster_path' : 'runtime']
# Out:
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                 NaN
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 2   https://en.wikipedia.org/wiki/The_Accidental_P...
# 4       https://en.wikipedia.org/wiki/Evening_Shadows
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 8   https://en.wikipedia.org/wiki/Manikarnika:_The...
# 10               https://en.wikipedia.org/wiki/Amavas
#
#                              title_y                    original_title  \
# 0           Uri: The Surgical Strike          Uri: The Surgical Strike
# ...

# %% [markdown]
# ### Filtering a DataFrame

# %%
movies.sample()
# Out:
#      title_x    imdb_id                                        poster_path  \
# 1594  Grahan  tt0275381  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                  wiki_link title_y original_title  is_adult  \
# 1594  https://en.wikipedia.org/wiki/Grahan  Grahan         Grahan         0
#
#       year_of_release runtime       genres  imdb_rating  imdb_votes  \
# 1594             2001     110  Crime|Drama          5.1          73
#
#                                                   story  \
# 1594  Widowed Chief Minister Jagdish Acharya lives a...
#
#                                                 summary tagline  \
# 1594  Widowed Chief Minister Jagdish Acharya lives a...     NaN
#
#                                                  actors wins_nominations  \
# 1594  Jackie Shroff|Manisha Koirala|Anupama Verma|Pr...              NaN
#
#                   release_date
# 1594  16 February 2001 (India)

# %%
ipl.sample()
# Out:
#           ID   City        Date Season MatchNumber             Team1  \
# 259  1136615  Delhi  2018-05-20   2018          55  Delhi Daredevils
#
#               Team2                 Venue        TossWinner TossDecision  \
# 259  Mumbai Indians  Arun Jaitley Stadium  Delhi Daredevils          bat
#
#     SuperOver       WinningTeam WonBy  Margin method Player_of_Match  \
# 259         N  Delhi Daredevils  Runs    11.0    NaN        A Mishra
#
#                                           Team1Players  \
# 259  ['PP Shaw', 'GJ Maxwell', 'SS Iyer', 'RR Pant'...
#
#                                           Team2Players          Umpire1  \
# 259  ['SA Yadav', 'E Lewis', 'Ishan Kishan', 'KA Po...  HDPK Dharmasena
#
#        Umpire2
# 259  CK Nandan

# %%
# find all the final winners

# Simple way.
mask = ipl['MatchNumber'] == 'Final'
new_dataframe = ipl[mask]
new_dataframe['WinningTeam']

# In single line
# ipl[ipl['MatchNumber'] == 'Final']['WinningTeam']
# Out:
# 0             Gujarat Titans
# 74       Chennai Super Kings
# 134           Mumbai Indians
# 194           Mumbai Indians
# 254      Chennai Super Kings
# 314           Mumbai Indians
# 373      Sunrisers Hyderabad
# 433           Mumbai Indians
# 492    Kolkata Knight Riders
# 552           Mumbai Indians
# 628    Kolkata Knight Riders
# 702      Chennai Super Kings
# 775      Chennai Super Kings
# 835          Deccan Chargers
# 892         Rajasthan Royals
# Name: WinningTeam, dtype: object

# %%
# how many matches are finishes in super over. 

mask = ipl['SuperOver'] == 'Y'
new_df = ipl[mask]
new_df.shape[0]

# In single line. 
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata
mask1 = ipl['City'] == 'Kolkata'
mask2 = ipl['WinningTeam'] == 'Chennai Super Kings'
ipl[mask1 & mask2].shape[0]

# In single line. 
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
mask = ipl['TossWinner'] == ipl['WinningTeam'] 
(ipl[mask].shape[0] / ipl.shape[0]) * 100


# In Single line 
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0] / ipl.shape[0]) * 100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes > 10000
mask1 = movies['imdb_rating'] > 8
mask2 = movies['imdb_votes'] > 10000

movies[mask1 & mask2].shape[0]

# In Single line. 
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5

mask1 = movies['genres'].str.split('|').apply(lambda x : 'Action' in x)
mask2 = movies['imdb_rating'] > 7.5
movies[mask1 & mask2].shape[0]

# movies[movies['genres'].str.contains('Action') & (movies['imdb_rating'] > 7.5)].shape[0]
# Out:
# 33

# %%
# write a function that can return the track record of 2 teams against each other
def track_record(team1, team2): 
    mateches_played = ipl[(ipl['Team1'] == team2) & (ipl['Team2'] == team1)].shape[0] + ipl[(ipl['Team1'] == team1) & (ipl['Team2'] == team2)].shape[0]
    # print(mateches_played)
    
    mask = (ipl['Team1'] == team2) & (ipl['Team2'] == team1)
    new_df1 = ipl[mask]
    gujrat_wins = new_df1[new_df1['WinningTeam'] == team2].shape[0]
    rajisthan_wins = new_df1[new_df1['WinningTeam'] == team1].shape[0]

    mask = (ipl['Team1'] == team1) & (ipl['Team2'] == team2)
    new_df1 = ipl[mask]
    gujrat_wins = gujrat_wins + new_df1[new_df1['WinningTeam'] == team2].shape[0]
    rajisthan_wins = rajisthan_wins + new_df1[new_df1['WinningTeam'] == team1].shape[0]

    return [rajisthan_wins, gujrat_wins, mateches_played]

team1 = 'Sunrisers Hyderabad'
team2 = 'Punjab Kings'
result = track_record(team1, team2)

print('Total Matches played between {} and {} is : {}'.format(team1, team2, result[2]))
print('{} wins {} matches'.format(team1, result[0]))
print('{} wins {} matches'.format(team2, result[1]))
# Out:
# Total Matches played between Sunrisers Hyderabad and Punjab Kings is : 4
# Sunrisers Hyderabad wins 2 matches
# Punjab Kings wins 2 matches

# %% [markdown]
# ### Adding new cols

# %%
# Completely new Column. 
movies['Country'] = 'India'
movies.sample(5)
# Out:
#                            title_x    imdb_id  \
# 895                       Malik Ek  tt1609147
# 725               Ata Pata Laapata  tt1956433
# 1269       Lucky: No Time for Love  tt0449306
# 351                       Saansein  tt5933706
# 1454  Kaise Kahoon Ke... Pyaar Hai  tt0366658
#
#                                             poster_path  \
# 895   https://upload.wikimedia.org/wikipedia/en/thum...
# 725   https://upload.wikimedia.org/wikipedia/en/thum...
# 1269  https://upload.wikimedia.org/wikipedia/en/thum...
# 351   https://upload.wikimedia.org/wikipedia/en/thum...
# 1454  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 895              https://en.wikipedia.org/wiki/Malik_Ek
# 725      https://en.wikipedia.org/wiki/Ata_Pata_Laapata
# 1269  https://en.wikipedia.org/wiki/Lucky:_No_Time_f...
# 351              https://en.wikipedia.org/wiki/Saansein
# 1454  https://en.wikipedia.org/wiki/Kaise_Kahoon_Ke....
#
# ...

# %%
# from Existing ones. 
movies.isnull().sum()
movies.dropna(subset=['actors'], inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1624 entries, 0 to 1628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1624 non-null   object
#  1   imdb_id           1624 non-null   object
#  2   poster_path       1524 non-null   object
#  3   wiki_link         1624 non-null   object
#  4   title_y           1624 non-null   object
#  5   original_title    1624 non-null   object
#  6   is_adult          1624 non-null   int64
#  7   year_of_release   1624 non-null   int64
#  8   runtime           1624 non-null   object
#  9   genres            1624 non-null   object
#  10  imdb_rating       1624 non-null   float64
#  11  imdb_votes        1624 non-null   int64
#  12  story             1607 non-null   object
#  13  summary           1624 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies['Lead_Actor'] = movies['actors'].str.split('|').apply(lambda x : x[0])
movies.sample(5)
# Out:
#                title_x    imdb_id  \
# 1061   Buddha Mar Gaya  tt1083447
# 618       Luv U Soniyo  tt2188811
# 301   Raman Raghav 2.0  tt5662932
# 276     Rocky Handsome  tt3410408
# 109    Khajoor Pe Atke  tt7260848
#
#                                             poster_path  \
# 1061  https://upload.wikimedia.org/wikipedia/en/thum...
# 618   https://upload.wikimedia.org/wikipedia/en/thum...
# 301   https://upload.wikimedia.org/wikipedia/en/thum...
# 276   https://upload.wikimedia.org/wikipedia/en/thum...
# 109   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link           title_y  \
# 1061   https://en.wikipedia.org/wiki/Buddha_Mar_Gaya   Buddha Mar Gaya
# 618       https://en.wikipedia.org/wiki/Luv_U_Soniyo      Luv U Soniyo
# 301   https://en.wikipedia.org/wiki/Raman_Raghav_2.0  Raman Raghav 2.0
# 276     https://en.wikipedia.org/wiki/Rocky_Handsome    Rocky Handsome
# ...

# %% [markdown]
# ### Important DataFrame Functions

# %%
# astype : Change the datatype of the columns in the dataframe.

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 932 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               932 non-null    int64
#  1   City             884 non-null    object
#  2   Date             932 non-null    object
#  3   Season           932 non-null    object
#  4   MatchNumber      932 non-null    object
#  5   Team1            932 non-null    object
#  6   Team2            932 non-null    object
#  7   Venue            932 non-null    object
#  8   TossWinner       932 non-null    object
#  9   TossDecision     932 non-null    object
#  10  SuperOver        932 non-null    object
#  11  WinningTeam      932 non-null    object
#  12  WonBy            932 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  932 non-null    object
#  16  Team1Players     932 non-null    object
# ...

# %%
# drop all missing values from the column Margin.
ipl.dropna(subset=['Margin'], inplace=True)

# %%
ipl['Margin'] = ipl['Margin'].astype('int8')

# %%
# Here we see that memory is decrese in the RAM
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 932 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               932 non-null    int64
#  1   City             884 non-null    object
#  2   Date             932 non-null    object
#  3   Season           932 non-null    object
#  4   MatchNumber      932 non-null    object
#  5   Team1            932 non-null    object
#  6   Team2            932 non-null    object
#  7   Venue            932 non-null    object
#  8   TossWinner       932 non-null    object
#  9   TossDecision     932 non-null    object
#  10  SuperOver        932 non-null    object
#  11  WinningTeam      932 non-null    object
#  12  WonBy            932 non-null    object
#  13  Margin           932 non-null    int8
#  14  method           19 non-null     object
#  15  Player_of_Match  932 non-null    object
#  16  Team1Players     932 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 932 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               932 non-null    int64
#  1   City             884 non-null    object
#  2   Date             932 non-null    object
#  3   Season           932 non-null    category
#  4   MatchNumber      932 non-null    object
#  5   Team1            932 non-null    category
#  6   Team2            932 non-null    category
#  7   Venue            932 non-null    object
#  8   TossWinner       932 non-null    object
#  9   TossDecision     932 non-null    object
#  10  SuperOver        932 non-null    object
#  11  WinningTeam      932 non-null    object
#  12  WonBy            932 non-null    object
#  13  Margin           932 non-null    int8
#  14  method           19 non-null     object
#  15  Player_of_Match  932 non-null    object
#  16  Team1Players     932 non-null    object
# ...

# %% [markdown]
# `NOTE : ` here we decrease the size of the dataframe, so it takes less space in memory, so it is recommanded always to convert the datatype in appropriate data type.

# %%
# value_counts function (works on Series and Dataframe both).

# %%
ipl['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 129
# Chennai Super Kings            121
# Kolkata Knight Riders          113
# Royal Challengers Bangalore    107
# Rajasthan Royals                94
# Kings XI Punjab                 85
# Sunrisers Hyderabad             74
# Delhi Daredevils                67
# Delhi Capitals                  33
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
ipl['Venue'].value_counts()
# Out:
# Venue
# Eden Gardens                                            77
# Wankhede Stadium                                        72
# M Chinnaswamy Stadium                                   62
# Feroz Shah Kotla                                        59
# Rajiv Gandhi International Stadium, Uppal               48
# MA Chidambaram Stadium, Chepauk                         47
# Sawai Mansingh Stadium                                  47
# Dubai International Cricket Stadium                     43
# Punjab Cricket Association Stadium, Mohali              35
# Wankhede Stadium, Mumbai                                31
# Sharjah Cricket Stadium                                 28
# Sheikh Zayed Stadium                                    27
# Maharashtra Cricket Association Stadium                 22
# Dr DY Patil Sports Academy, Mumbai                      20
# Brabourne Stadium, Mumbai                               17
# Dr DY Patil Sports Academy                              17
# ...

# %%
ipl['SuperOver'].value_counts()
# Out:
# SuperOver
# N    932
# Name: count, dtype: int64

# %%
movies['Lead_Actor'].value_counts().head(20)
# Out:
# Lead_Actor
# Akshay Kumar        51
# Amitabh Bachchan    49
# Ajay Devgn          42
# Salman Khan         32
# Sanjay Dutt         30
# Shah Rukh Khan      24
# Sunny Deol          22
# Emraan Hashmi       21
# Saif Ali Khan       20
# John Abraham        18
# Arjun Rampal        18
# Tusshar Kapoor      17
# Shahid Kapoor       17
# Jimmy Sheirgill     16
# Manoj Bajpayee      15
# Hrithik Roshan      14
# Anil Kapoor         14
# Naseeruddin Shah    14
# Irrfan Khan         14
# Govinda             14
# Name: count, dtype: int64

# %%
# find which player has won most potm -> in finals and qualifiers 
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets       7    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets       7    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
new_df = ipl[~ipl['MatchNumber'].str.isdigit()]
new_df['Player_of_Match'].value_counts().head()
# Out:
# Player_of_Match
# F du Plessis      3
# SK Raina          3
# KA Pollard        3
# JJ Bumrah         2
# AB de Villiers    2
# Name: count, dtype: int64

# %% [markdown]
# `NOTE : ` We can apply plot function on series and provide what kind of plot we want.

# %%
# Toss decision plot
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played

(ipl['Team2'].value_counts() + ipl['Team1'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 227
# Royal Challengers Bangalore    220
# Kolkata Knight Riders          219
# Chennai Super Kings            207
# Rajasthan Royals               187
# Kings XI Punjab                186
# Delhi Daredevils               158
# Sunrisers Hyderabad            148
# Deccan Chargers                 75
# Delhi Capitals                  60
# Pune Warriors                   45
# Gujarat Lions                   29
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sort_values(series and dataframe) -> ascending -> na_position -> inplace -> multiple cols

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.sort_values('title_x', ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# #### How to handle NaN values in sort_values function.

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name')
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name', na_position='first', ascending=False)
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
students.sort_values('name', na_position='last')
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
# How to handle two columns of a dataframe in sort_values function.

# %%
# we need to sort the values on year_of_release, In each year release all the movies are alphabtically sorted.
movies.sort_values(['year_of_release', 'title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# sort according to the year of release and descending according to the title
movies.sort_values(['year_of_release', 'title_x'], ascending=[True, False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...
